# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
pd.options.display.max_rows = 999

# %%
complaints = pd.read_csv("allegations_20200726939.csv")

# %%
complaints
# Out:
#        unique_mos_id first_name last_name command_now  complaint_id  \
# 0              10004   Jonathan      Ruiz     078 PCT         42835
# 1              10007       John     Sears     078 PCT         24601
# 2              10007       John     Sears     078 PCT         24601
# 3              10007       John     Sears     078 PCT         26146
# 4              10009      Noemi    Sierra     078 PCT         40253
# ...              ...        ...       ...         ...           ...
# 33353           9992     Tomasz  Pulawski     078 PCT         35671
# 33354           9992     Tomasz  Pulawski     078 PCT         35671
# 33355           9992     Tomasz  Pulawski     078 PCT         35671
# 33356           9992     Tomasz  Pulawski     078 PCT         35671
# 33357           9992     Tomasz  Pulawski     078 PCT         35671
#
#        month_received  year_received  month_closed  year_closed  \
# 0                   7           2019             5         2020
# ...

# %%
complaints['command_at_incident'].head(60)
# Out:
# 0     078 PCT
# 1        PBBS
# 2        PBBS
# 3        PBBS
# 4     078 PCT
# 5     078 PCT
# 6     078 PCT
# 7     078 PCT
# 8     078 PCT
# 9     078 PCT
# 10    078 PCT
# 11    078 PCT
# 12    079 PCT
# 13    079 PCT
# 14    079 PCT
# 15    079 PCT
# 16    079 PCT
# 17    079 PCT
# 18    079 PCT
# 19    079 PCT
# 20    079 PCT
# 21    079 PCT
# 22    079 PCT
# 23    079 PCT
# 24    079 PCT
# 25    079 PCT
# 26    079 PCT
# 27    079 PCT
# 28    079 PCT
# 29    079 PCT
# 30    067 PCT
# 31    PBBS SU
# 32    PBBS SU
# 33    PBBS SU
# 34    PBBS SU
# 35    067 PCT
# 36    PBBS SU
# 37    PBBS SU
# 38    079 PCT
# 39    079 PCT
# 40    079 PCT
# 41    079 PCT
# 42    PBBN SU
# 43    PBBN SU
# 44    PBBN SU
# 45    PBBN SU
# 46    PBBN SU
# 47    073 DET
# 48    073 DET
# 49      PSA 2
# 50      PSA 3
# 51      PSA 3
# 52      PSA 3
# 53      PSA 3
# 54      PSA 3
# 55    NARCBBN
# 56      PSA 3
# 57      PSA 3
# 58      PSA 3
# 59      PSA 3
# ...

# %%
complaints.columns
# Out:
# Index(['unique_mos_id', 'first_name', 'last_name', 'command_now',
#        'complaint_id', 'month_received', 'year_received', 'month_closed',
#        'year_closed', 'command_at_incident', 'rank_abbrev_incident',
#        'rank_abbrev_now', 'rank_now', 'rank_incident', 'mos_ethnicity',
#        'mos_gender', 'mos_age_incident', 'complainant_ethnicity',
#        'complainant_gender', 'complainant_age_incident', 'fado_type',
#        'allegation', 'precinct', 'contact_reason', 'outcome_description',
#        'board_disposition'],
#       dtype='object')

# %%
# to group by precinct mos was at when incident occured 
# complaints.groupby('precinct')

# %%
complaints['precinct'].values
# Out:
# array([78., 67., 67., ..., 66., 66., 66.])

# %%
students_df.loc[2:10,"studcity":'studareacode']

# %%
complaints.groupby('command_now').count()
# Out:
#              unique_mos_id  first_name  last_name  complaint_id  \
# command_now
# 001 DET                 18          18         18            18
# 001 PCT                 67          67         67            67
# 005 DET                 49          49         49            49
# 005 PCT                 52          52         52            52
# 006 PCT                 88          88         88            88
# 007 DET                  6           6          6             6
# 007 PCT                 43          43         43            43
# 009 DET                 30          30         30            30
# 009 PCT                130         130        130           130
# 010 DET                  5           5          5             5
# 010 PCT                 40          40         40            40
# 013 DET                 29          29         29            29
# 013 PCT                 35          35         35            35
# ...

# %%
complaints.groupby('precinct').count()
# Out:
#           unique_mos_id  first_name  last_name  command_now  complaint_id  \
# precinct
# 0.0                  21          21         21           21            21
# 1.0                 174         174        174          174           174
# 5.0                 160         160        160          160           160
# 6.0                 175         175        175          175           175
# 7.0                 221         221        221          221           221
# 9.0                 266         266        266          266           266
# 10.0                241         241        241          241           241
# 13.0                152         152        152          152           152
# 14.0                351         351        351          351           351
# 17.0                 76          76         76           76            76
# 18.0                268         268        268          268           268
# ...

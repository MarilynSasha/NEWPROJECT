# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
pd.options.display.max_rows = 999

# %%
complaints = pd.read_csv("allegations_20200726939.csv")

# %%
complaints
# Out:
#        unique_mos_id first_name last_name command_now  complaint_id  \
# 0              10004   Jonathan      Ruiz     078 PCT         42835
# 1              10007       John     Sears     078 PCT         24601
# 2              10007       John     Sears     078 PCT         24601
# 3              10007       John     Sears     078 PCT         26146
# 4              10009      Noemi    Sierra     078 PCT         40253
# ...              ...        ...       ...         ...           ...
# 33353           9992     Tomasz  Pulawski     078 PCT         35671
# 33354           9992     Tomasz  Pulawski     078 PCT         35671
# 33355           9992     Tomasz  Pulawski     078 PCT         35671
# 33356           9992     Tomasz  Pulawski     078 PCT         35671
# 33357           9992     Tomasz  Pulawski     078 PCT         35671
#
#        month_received  year_received  month_closed  year_closed  \
# 0                   7           2019             5         2020
# ...

# %%
complaints['command_at_incident'].head(60)
# Out:
# 0     078 PCT
# 1        PBBS
# 2        PBBS
# 3        PBBS
# 4     078 PCT
# 5     078 PCT
# 6     078 PCT
# 7     078 PCT
# 8     078 PCT
# 9     078 PCT
# 10    078 PCT
# 11    078 PCT
# 12    079 PCT
# 13    079 PCT
# 14    079 PCT
# 15    079 PCT
# 16    079 PCT
# 17    079 PCT
# 18    079 PCT
# 19    079 PCT
# 20    079 PCT
# 21    079 PCT
# 22    079 PCT
# 23    079 PCT
# 24    079 PCT
# 25    079 PCT
# 26    079 PCT
# 27    079 PCT
# 28    079 PCT
# 29    079 PCT
# 30    067 PCT
# 31    PBBS SU
# 32    PBBS SU
# 33    PBBS SU
# 34    PBBS SU
# 35    067 PCT
# 36    PBBS SU
# 37    PBBS SU
# 38    079 PCT
# 39    079 PCT
# 40    079 PCT
# 41    079 PCT
# 42    PBBN SU
# 43    PBBN SU
# 44    PBBN SU
# 45    PBBN SU
# 46    PBBN SU
# 47    073 DET
# 48    073 DET
# 49      PSA 2
# 50      PSA 3
# 51      PSA 3
# 52      PSA 3
# 53      PSA 3
# 54      PSA 3
# 55    NARCBBN
# 56      PSA 3
# 57      PSA 3
# 58      PSA 3
# 59      PSA 3
# ...

# %%
complaints.columns
# Out:
# Index(['unique_mos_id', 'first_name', 'last_name', 'command_now',
#        'complaint_id', 'month_received', 'year_received', 'month_closed',
#        'year_closed', 'command_at_incident', 'rank_abbrev_incident',
#        'rank_abbrev_now', 'rank_now', 'rank_incident', 'mos_ethnicity',
#        'mos_gender', 'mos_age_incident', 'complainant_ethnicity',
#        'complainant_gender', 'complainant_age_incident', 'fado_type',
#        'allegation', 'precinct', 'contact_reason', 'outcome_description',
#        'board_disposition'],
#       dtype='object')

# %%
# to group by precinct mos was at when incident occured 
# complaints.groupby('precinct')

# %%
complaints['command_at_incident'].values
# Out:
# array(['078 PCT', 'PBBS', 'PBBS', ..., '066 PCT', '066 PCT', '066 PCT'],
#       dtype=object)

# %%
complaints['command_now'].values
# Out:
# array(['078 PCT', '078 PCT', '078 PCT', ..., '078 PCT', '078 PCT',
#        '078 PCT'], dtype=object)

# %%
complaints.groupby('command_now').count()
# Out:
#              unique_mos_id  first_name  last_name  complaint_id  \
# command_now
# 001 DET                 18          18         18            18
# 001 PCT                 67          67         67            67
# 005 DET                 49          49         49            49
# 005 PCT                 52          52         52            52
# 006 PCT                 88          88         88            88
# 007 DET                  6           6          6             6
# 007 PCT                 43          43         43            43
# 009 DET                 30          30         30            30
# 009 PCT                130         130        130           130
# 010 DET                  5           5          5             5
# 010 PCT                 40          40         40            40
# 013 DET                 29          29         29            29
# 013 PCT                 35          35         35            35
# ...

# %%
complaints.groupby('command_at_incident').count()
# Out:
#                      unique_mos_id  first_name  last_name  command_now  \
# command_at_incident
# 001 DET                          2           2          2            2
# 001 PCT                        102         102        102          102
# 005 PCT                         81          81         81           81
# 006 DET                          1           1          1            1
# 006 PCT                        123         123        123          123
# 007 DET                          4           4          4            4
# 007 PCT                        135         135        135          135
# 009 PCT                        148         148        148          148
# 010 DET                          3           3          3            3
# 010 PCT                        146         146        146          146
# 013 DET                          8           8          8            8
# 013 PCT                         65          65         65           65
# ...

# %%
complaints.groupby('unique_mos_id').count()
# Out:
#                first_name  last_name  command_now  complaint_id  \
# unique_mos_id
# 2                      10         10           10            10
# 5                       3          3            3             3
# 11                      5          5            5             5
# 21                      8          8            8             8
# 23                     14         14           14            14
# ...                   ...        ...          ...           ...
# 36301                   3          3            3             3
# 36305                   3          3            3             3
# 36317                   2          2            2             2
# 36339                   3          3            3             3
# 36374                  15         15           15            15
#
#                month_received  year_received  month_closed  year_closed  \
# unique_mos_id
# 2                          10             10            10           10
# ...

# %%
complaints['unique_mos_id'] == 9992
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 33353     True
# 33354     True
# 33355     True
# 33356     True
# 33357     True
# Name: unique_mos_id, Length: 33358, dtype: bool

# %%
# create an array of just these values 

x = complaints['command_at_incident'].values
x
# Out:
# array(['078 PCT', 'PBBS', 'PBBS', ..., '066 PCT', '066 PCT', '066 PCT'],
#       dtype=object)

# %%
y = sns.countplot(x='command_at_incident', hue='unique_mos_id', data=complaints)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-57-240829e11381> in <module>
# ----> 1 y = sns.countplot(x='command_at_incident', hue='unique_mos_id', data=complaints)
#
# ~/miniconda3/lib/python3.7/site-packages/seaborn/categorical.py in countplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, dodge, ax, **kwargs)
#    3550                           estimator, ci, n_boot, units, seed,
#    3551                           orient, color, palette, saturation,
# -> 3552                           errcolor, errwidth, capsize, dodge)
#    3553
#    3554     plotter.value_label = "count"
#
# ~/miniconda3/lib/python3.7/site-packages/seaborn/categorical.py in __init__(self, x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge)
# ...

# %%
corr_dataframe = complaints[['command_at_incident', 'unique_mos_id', 'command_now']].corr()
corr_dataframe

# %%
sns.countplot(x='command_at_incident', hue='unique_mos_id', data=complaints)

# %%
sns.pairplot(complaints, plot_kws = {"color": "green"})
